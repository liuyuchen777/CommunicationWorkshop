# %%
import matplotlib.pyplot as plt
import numpy as np 
from scipy import special
# x label
x = np.linspace(0, 10, num=11)
# read data
y2 = np.loadtxt('awgn.txt')
y2 = y2[:,1]
# therotical data
y1 = 0.5*special.erfc(np.sqrt(np.exp(x*np.log(10)/10)))
# plot figure
plt.xlabel('$E_b/N_0 (dB)$')
plt.ylabel('Average BER')

plt.xlim(0,10)
plt.ylim(0.0000001, 1)

plt.semilogy(x, y1, label = "OFDM AWGN Theory")
plt.semilogy(x, y2, linewidth = 0,  marker = '^', markersize = 5, label = "OFDM AWGN Simulation")

plt.grid(linestyle='-.')

plt.legend(loc = 'upper right')

plt.show()

plt.savefig('ofdm_awgn.eps', format = 'eps')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-e2020ae6a699> in <module>
#       6 # read data
#       7 y2 = np.loadtxt('awgn.txt')
# ----> 8 y2 = y2[:,1]
#       9 # therotical data
#      10 y1 = 0.5*special.erfc(np.sqrt(np.exp(x*np.log(10)/10)))
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
import matplotlib.pyplot as plt
import numpy as np 
from scipy import special
# x label
x = np.linspace(0, 30, num=31)
# read data
y2 = np.loadtxt('rayleigh_ofdm.txt')
y2 = y2[:,1]
# therotical data
y1 = 0.5*(1-np.sqrt((10**(x/10))/(10**(x/10)+1)))
# plot figure
plt.xlabel('$E_b/N_0 (dB)$')
plt.ylabel('Average BER')

plt.xlim(0,30)
plt.ylim(0.00001, 1)

plt.semilogy(x, y1, label = "OFDM Rayleigh Theory")
plt.semilogy(x, y2, marker = 'o', markersize = 5, label = "OFDM Rayleigh Simulation")

plt.grid(linestyle='-.')

plt.legend(loc = 'upper right')

plt.show()

plt.savefig('ofdm_rayleigh.eps', format = 'eps')

# %%
import numpy as np 
from scipy import special
# x label
x = np.linspace(0, 30, num=31)
# read data
y2 = np.loadtxt('select_ofdm_d1.txt')
y2 = y2[:,1]
y3 = np.loadtxt('select_ofdm_d5.txt')
y3 = y3[:,1]
y4 = np.loadtxt('select_ofdm_d20.txt')
y4 = y4[:,1]
# therotical data
y1 = 0.5*(1-np.sqrt((10**(x/10))/(10**(x/10)+1)))
# plot figure
plt.xlabel('$E_b/N_0 (dB)$')
plt.ylabel('Average BER')

plt.xlim(0,30)
plt.ylim(0.00001, 1)

plt.semilogy(x, y1, label = "OFDM Rayleigh Theory")
plt.semilogy(x, y2, marker = 'o', markersize = 5, label = "OFDM Simulation Delay = 1")
plt.semilogy(x, y3, marker = 'd', markersize = 5, label = "OFDM Simulation Delay = 5")
plt.semilogy(x, y4, marker = 'x', markersize = 5,  label = "OFDM Simulation Delay = 20")

plt.grid(linestyle='-.')

plt.legend(loc = 'upper right')

plt.show()

plt.savefig('ofdm_select.eps', format = 'eps')

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = np.linspace(0.0, 0.25, num=250)
y = np.sin(2 * np.pi * 50 * x) + np.sin(2 * np.pi * 120 * x)
y = y + np.random.randn(y.size)/2
plt.plot(x, y)
plt.title('Noisy Time Domain Signal')
plt.show()

# %%
fft_y = np.fft.fft(y, n=251)
amy = fft_y * fft_y.conj() / 251
f = 1000 / 251 * np.arange(127)
plt.plot(f, amy[1:128])
plt.xlabel('Frequency (Hz)')
plt.title('Power Spectral Density')
plt.show()
